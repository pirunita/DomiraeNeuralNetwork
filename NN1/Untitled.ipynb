# %% [markdown]
# # Question1
# ## Design a MLP to approximate the following 2D function:

# %%
# Module
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D

# %%
# Dataset Loader
min_value, max_value = (-2, 2)
data_size = 500
train_ratio = 0.85
test_ratio = 0.15
x = np.random.uniform(low=min_value, high=max_value, size=(data_size,))
y = np.random.uniform(low=min_value, high=max_value, size=(data_size,))

# Train / Test split
split_index = int(data_size * train_ratio) 
x_train = x[:split_index]
y_train = y[:split_index]
x_test = x[split_index:]
y_test = y[split_index:]

# %%
#x, y = np.meshgrid(np.linspace(-2, 2, 0.2), np.linspace(-2, 2, 0.2))

gaussian_noise = np.random.normal(0, 1, (data_size,))

numerator = 1 + np.cos(12 * np.sqrt(x**2 + y**2))
denominator = 0.5 * (x**2 + y**2) + 2

function = -numerator / denominator 
function += gaussian_noise
print(function.shape)
# Out:
# (500,)

# %%
# loss function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# visualize
fig = plt.figure()
ax = plt.subplot(1, 1, 1, projection='3d')
ax.plot_surface(x, y, function, label='Drop-Wave Function')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-0710f8f3deae> in <module>()
#       2 fig = plt.figure()
#       3 ax = plt.subplot(1, 1, 1, projection='3d')
# ----> 4 ax.plot_surface(x, y, function, label='Drop-Wave Function')
#       5 plt.show()
#
# ~/anaconda3/envs/sp/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1634
#    1635         if Z.ndim != 2:
# -> 1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#    1638         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
mu, sigma = 0, 1
gaussian_noise = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(gaussian_noise, 30, normed=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ), linewidth=2, color='r')
plt.show()
# Out:
# /Users/khosungpil/anaconda3/envs/sp/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
